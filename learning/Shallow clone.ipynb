# %%
# %sql
drop table if exists orders_managed;

create table orders_managed (
  order_id long,
  sku string,
  product_name string,
  category string,
  quantity long,
  price double
);

alter table orders_managed add constraint valid_qty check(quantity > 0);

# %%
# %sql
desc history orders_managed;

# %%
# %sql
insert into orders_managed values
(1,"sku-101", "waireless mouse","Electronics", 2,200),
(2,"sku-102", "waireless mouse","Electronics", 8,300),
(3,"sku-103", "waireless mouse","Electronics", 20,890),
(4,"sku-104", "waireless mouse","Electronics", 21,8000),
(5,"sku-105", "waireless mouse","Electronics", 12,900)

# %%
# %sql
desc history orders_managed;
    
select * from orders_managed;

# %%
# %sql
desc history orders_managed;

# %%
# %sql
insert into orders_managed values
(6,"sku-106", "waireless mouse","Electronics", 20,100),
(7,"sku-107", "waireless mouse","Electronics", 80,400),
(8,"sku-108", "waireless mouse","Electronics", 28,790)

# %%
# %sql
select * from orders_managed

# %%
# %sql
desc history orders_managed;

# %%
# %sql
delete from orders_managed
where order_id = 1;

# %%
# %sql
select * from orders_managed

# %%
# %sql
desc history orders_managed;

# %%
# %sql
update orders_managed
set quantity=1000
where order_id=8

# %%
# %sql
desc history orders_managed;

# %%
# %sql
insert into orders_managed values
(9,"sku-109", "waireless mouse","Electronics", 2098,10009),
(10,"sku-1010", "waireless mouse","Electronics", 8067,40087)

# %%
# %sql
desc history orders_managed;

# %%
# %sql
select * from orders_managed

# %%
# %sql
select distinct _metadata.file_path from orders_managed;

# %%
# %sql
desc detail orders_managed

# %%
# %sql
drop table if exists orders_managed_sclone;

create table orders_managed_sclone shallow clone orders_managed;

desc detail orders_managed_sclone;

# %%
# %sql
select * from orders_managed order by order_id;

# %%
# %sql
select * from orders_managed_sclone order by order_id;

# %%
# %sql
insert into orders_managed values
(11,"sku-1011", "waireless mouse","Electronics", 546,432)

# %%
# %sql
insert into orders_managed_sclone values
(65,"sku-1065", "waireless mouse","Electronics", 654,5444)

# %%
# %sql
select * from orders_managed order by order_id;

# %%
# %sql
select * from orders_managed_sclone order by order_id;

# %%
# %sql
delete from orders_managed_sclone
where order_id=6

# %%
# %sql
select * from orders_managed order by order_id;

# %%
# %sql
select * from orders_managed_sclone order by order_id;

# %%
# %sql
delete from orders_managed;

# %%
# %sql
select * from orders_managed;

# %%
# %sql
alter table orders_managed
set tblproperties('delta.deletedFileRetentionDuration' = 'interval 0 hours')

# %%
# %sql
vacuum orders_managed dry run;

# %%
# %sql
vacuum orders_managed

# %%
# %sql
desc history orders_managed_sclone;

# %%
# %sql
select distinct _metadata.file_path from orders_managed_sclone;

# %%
# %sql
select * from orders_managed_sclone;

# %%
# %sql
select * from orders_managed@v9 order by order_id;

# %%
# %sql
select distinct _metadata.file_path from orders_managed@v9;

# %%
# %sql
delete from orders_managed_sclone;

# %%
# %sql
alter table orders_managed_sclone
set tblproperties('delta.deletedFileRetentionDuration' = 'interval 0 hours')

# %%
# %sql
vacuum orders_managed_sclone dry run;

# %%
# %sql
restore table orders_managed to version as of 8;

# %%
# %sql
drop table orders_managed;

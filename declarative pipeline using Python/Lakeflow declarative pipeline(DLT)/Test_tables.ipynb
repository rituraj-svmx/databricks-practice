# %%
# %sql
select * from orders_silver where order_id=400;

# %%
# %sql
select * from customer_silver where customer_id=80;

# %%
# %sql
select * from city_wise_sales_gold;

# %%
# %sql
desc extended city_wise_sales_gold;

# %%
display(dbutils.fs.ls('/Volumes/sales_catalog/default/sales_data'))

# %%
customers_df = (spark.
 read.
 format("csv")
 .option("header", "true")
 .option("inferSchema", "true")
 .load("/Volumes/lakeflow_job/default/ranjan_volume/inputdata/customers"))

# %%
spark.sql("create schema if not exists lakeflow_job.bronze")
customers_df.write.format("delta").mode("overwrite").saveAsTable("lakeflow_job.bronze.customers_bronze")

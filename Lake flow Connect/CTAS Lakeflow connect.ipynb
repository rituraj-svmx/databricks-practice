# %% [markdown]
# ## Batch Mode ingestion (CTAS)

# %%
# %sql
select current_catalog();

# %%
# %sql
create volume Lateflow_connect_volume;

# %%
dbutils.fs.ls("dbfs:/Volumes/workspace/default/lateflow_connect_volume")

# %%
dbutils.fs.mkdirs("/Volumes/workspace/default/lateflow_connect_volume/orders_data")

# %%
# %sql
select * from CSV.`/Volumes/workspace/default/lateflow_connect_volume/orders_data`

# %%
# %sql
drop table if exists orders;
    
create table orders as 
select * from 
read_files(
  '/Volumes/workspace/default/lateflow_connect_volume/orders_data', 
  format=> 'csv')

# %%
# %sql
select * from orders

# %% [markdown]
# ### upload another files in the volume with same structure

# %%
# %sql
drop table if exists orders;
    
create table orders as 
select * from 
read_files(
  '/Volumes/workspace/default/lateflow_connect_volume/orders_data', 
  format=> 'csv')

# %%
# %sql 
select * from orders;

# %% [markdown]
# ###Upload another file with extra column

# %%
# %sql
drop table if exists orders;
    
create table orders as 
select * from 
read_files(
  '/Volumes/workspace/default/lateflow_connect_volume/orders_data', 
  format=> 'csv')

# %%
# %sql
select * from orders;

# %% [markdown]
# ### upload another file with mismatch schema ie different data types

# %%
# %sql
drop table if exists orders;
    
create table orders as 
select * from 
read_files(
  '/Volumes/workspace/default/lateflow_connect_volume/orders_data', 
  format=> 'csv')

# %%
# %sql
select * from orders;

# %%
# %sql 
desc formatted orders;

# %% [markdown]
# ### since its a infer schema thats why for customer id it takes as string.
# ### incase of inforce schema it would have failed . see below example

# %% [markdown]
# ## mode=> 'PERMISSIVE'

# %%
# %sql
drop table if exists orders;
    
create table orders as 
select * from 
read_files(
  '/Volumes/workspace/default/lateflow_connect_volume/orders_data', 
  format=> 'csv',
  schema => 'order_id int, order_date date, order_customer_id int, order_status string, _rescued_data string',
  header => true,
  mode => 'PERMISSIVE',
  columnNameOfCorruptRecord => '_rescued_data'
)

# %%
# %sql 
select * from orders;

# %% [markdown]
# ### mode=>"dropMalformed"

# %%
# %sql
drop table if exists orders;
    
create table orders as 
select * from 
read_files(
  '/Volumes/workspace/default/lateflow_connect_volume/orders_data', 
  format=> 'csv',
  schema => 'order_id int, order_date date, order_customer_id int, order_status string, _rescued_data string',
  header => true,
  mode => 'DROPMALFORMED'
)

# %%
# %sql
SELECT * from orders;

# %% [markdown]
# %md
# ### mode=>"FAILFAST"

# %%
# %sql
drop table if exists orders;
    
create table orders as 
select * from 
read_files(
  '/Volumes/workspace/default/lateflow_connect_volume/orders_data', 
  format=> 'csv',
  schema => 'order_id int, order_date date, order_customer_id int, order_status string, _rescued_data string',
  header => true,
  mode => 'FAILFAST',
  columnNameOfCorruptRecord => '_rescued_data'
)

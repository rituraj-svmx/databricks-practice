# %% [markdown]
# ## COPY INTO with no schema defined for a target table

# %%
# %sql
select current_catalog();

# %%
dbutils.fs.ls("dbfs:/Volumes/workspace/default/lateflow_connect_volume")

# %%
dbutils.fs.mkdirs("/Volumes/workspace/default/lateflow_connect_volume/orders_data")

# %% [markdown]
# ### table with no schema

# %%
# %sql
drop table if exists orders;

create table orders;

# %% [markdown]
# ### Copy INTO
# #### upload first file in the above volume
# #### create table without schema & disable inferschema
# #### without copyoption

# %%
# %sql
copy into orders
from "/Volumes/workspace/default/lateflow_connect_volume/orders_data"
fileformat = CSV
FORMAT_OPTIONS(
    'header' = 'true',
    'delimiter' = ','
)

# %% [markdown]
# ### with COPY_OPTION (MERGESCHEMA enabled)

# %%
# %sql
copy into orders
from "/Volumes/workspace/default/lateflow_connect_volume/orders_data"
fileformat = CSV
FORMAT_OPTIONS(
    'header' = 'true',
    'delimiter' = ','
)
COPY_OPTIONS(
  'mergeSchema' = 'true'
)

# %%
# %sql
desc extended orders;

# %% [markdown]
# ### to ingest another file , you can disable copy_option. it should work

# %%
# %sql 
copy into orders
from '/Volumes/workspace/default/lateflow_connect_volume/orders_data'
fileformat = CSV
FORMAT_OPTIONS(
    'header' = 'true',
    'delimiter' = ',' )

# %%
# %sql
select * from orders;

# %%
# %sql
select * from orders;

# %% [markdown]
# ### Ingest another file with extra column(different schema than the target table has)
# ### without COPY_OPTION > it will throw error

# %%
# %sql
copy into orders
from '/Volumes/workspace/default/lateflow_connect_volume/orders_data'
fileformat = CSV
FORMAT_OPTIONS(
    'header' = 'true',
    'delimiter' = ',' )

# %% [markdown]
# ### with COPY_OPTION

# %%
# %sql
copy into orders
from '/Volumes/workspace/default/lateflow_connect_volume/orders_data'
fileformat = CSV
FORMAT_OPTIONS(
    'header' = 'true',
    'delimiter' = ',' )
COPY_OPTIONS(
  'mergeSchema' = 'true'
)

# %%
# %sql 
desc extended orders;

# %%
# %sql
select * from orders;

# %%
# %sql 
copy into orders
from '/Volumes/workspace/default/lateflow_connect_volume/orders_data'
fileformat = CSV
FORMAT_OPTIONS(
    'header' = 'true',
    'delimiter' = ','
)

# %%
# %sql
desc extended orders;

# %%
# %sql
SELECT * from orders;

# %% [markdown]
# ### enable InferSchema

# %%
# %sql
drop table if exists orders;
create table orders;

# %%
# %sql
copy into orders
from '/Volumes/workspace/default/lateflow_connect_volume/orders_data'
fileformat = CSV
FORMAT_OPTIONS('header' = 'true', 'delimiter' = ',', 'inferSchema' = 'true')
COPY_OPTIONS(
  'mergeSchema' = 'true'
)

# %%
# %sql
desc extended orders

# %%
# %sql
copy into orders
from '/Volumes/workspace/default/lateflow_connect_volume/orders_data'
fileformat = CSV
FORMAT_OPTIONS('header' = 'true', 'delimiter' = ',', 'inferSchema' = 'true')

# %%
# %sql
select * from orders

# %% [markdown]
# ### COPY INTO is an IDEMPOTENT operation , meaning exactly once.
# #### it create a folder inside _delta_log named _copy_into_log which will help to ingest only new data/files

# %%
# %sql
copy into orders
from '/Volumes/workspace/default/lateflow_connect_volume/orders_data'
fileformat = CSV
FORMAT_OPTIONS('header' = 'true', 'delimiter' = ',', 'inferSchema' = 'true')

# %%
# %sql
copy into orders
from '/Volumes/workspace/default/lateflow_connect_volume/orders_data'
fileformat = CSV
FORMAT_OPTIONS(
  'header' = 'true', 
  'delimiter' = ',', 
  'inferSchema' = 'true',
  'mergeSchema' = 'true'
  )

# %%
# %sql
desc extended orders;

# %%
# %sql
copy into orders
from '/Volumes/workspace/default/lateflow_connect_volume/orders_data'
fileformat = CSV
FORMAT_OPTIONS(
  'header' = 'true', 
  'delimiter' = ',', 
  'inferSchema' = 'true',
  'mergeSchema' = 'true')
COPY_OPTIONS(
  'mergeSchema' = 'true'
)

# %%
# %sql
select * from orders;

# %%
# %sql
desc extended orders;

# %% [markdown]
# #### Ingest will fail as data type is not matched

# %%
# %sql
copy into orders
from '/Volumes/workspace/default/lateflow_connect_volume/orders_data'
fileformat = CSV
FORMAT_OPTIONS(
  'header' = 'true', 
  'delimiter' = ',', 
  'inferSchema' = 'true',
  'mergeSchema' = 'true'
)

# %%
# %sql
copy into orders
from '/Volumes/workspace/default/lateflow_connect_volume/orders_data'
fileformat = CSV
FORMAT_OPTIONS(
  'header' = 'true', 
  'delimiter' = ',', 
  'inferSchema' = 'true',
  'mergeSchema' = 'true'
)
COPY_OPTIONS(
  'mergeSchema' = 'true')

# %%
frozenset = frozenset({1,2,3})

# %%
list = [1,2,3,4]
tuple = ()
set = {}
dict = {1:1, 2:2}

# %%
help('keywords')

# %%
# objects are immutable 
import sys
x = 2345677
print(sys.getrefcount(x))

y = x
print(sys.getrefcount(x))

# %%
a = 0 

if a>0:
    print("i'm inside if block")
elif a==0:
    print("im inside elif")
else:
    print("I'm inside else")

print("i'm outside of loo")

# %%
a = 15
b = 12
if a*b>100:
    print(a+b)
else:
    print(a*b)

# %%
h = 10 
d = 13
r = d/2

print((3.14 * r ** 2 * h)/3)

# %% [markdown]
# ## zip() interate over multiple data structures

# %%
name = ('Shaun', 'Ron', 'Michael')
seat_numbers = (101, 102, 103)

students_seat = dict()

for i, j in zip(name, seat_numbers):
    students_seat[i] = j
print(students_seat)

# %%
num = -6

if num > 0:
    num + 1
    print(num)
else:
    num = num - 1
    print(num)

# %%
a = 5
b = 2
c = 8
d = 7

x = ((((a + b) * (a + c) * (a + d)) /
       ((b + a) * (b + c) * (b + d)) / 
       ((c + a) * (c + b) * (c + d))) *
      (a * b * c * d))

print(x)

# %%
a = 5 
b = 9 

if a == b:
    print("a is equal to b")

elif a > b:
    print("a is greater than b")

else:
    print("a is less than b")

# %%
mySet = {5, 7, 2, 6, 3}

print(10 in mySet)
print(7 in mySet)

# %%
a = 12

if a%3 == 0 and a%5==0:
    print("a is divsible by 3 & 5")

elif a%3 == 0 or a%5==0:
    print("a is divsible by either 3 or 5 not both")

else:
    print("a is not divisible by 3 or 5")

# %%
year = 1996

if year%4 == 0:
    print("year is leap year")

# %% [markdown]
# # sep="\n"

# %%
#Name, Age, Roll Number, & Subjects

Name = 'John'
Age = 20
Roll_Number = 101
Subjects = ['Math', 'Science', 'English']

print(Name, Age, Roll_Number, Subjects, sep="\n")

# %%
fruits = ['Apple', 'Grapes', 'Orange', 'Pineapple', 'Watermelon']

print(fruits[2])

# %%
fruit_list = ['Apple', 'Grapes', 'Orange', 'Pineapple', 'Watermelon']
fruit_string = 'Mango'

print(fruit_list + [a])

# %%
cityList = ['London', 'New York', 'Delhi']

print(cityList*3)

# %%
cityList = ['London', 'New York', 'Delhi', 'Mumbai', 'Paris']

print("delhi" in cityList)

# %%
msg = 'A bright sunny day'

print(msg[9:14])

# %%
cityList = ['London', 'New York', 'Delhi', 'Mumbai', 'Paris']

print("Delhi" in cityList)
print("London" in cityList)

# %%
name = 'P y t h o n'

print(name[::2])

# %%
name = 'Python'

print(name.index('h'))

# %%
myList = ['Red', 'Blue', 'Orange', 'White', 'Black', 'Yellow']

print(myList[1::2])

# %%
languages = "Java, Python, C++, Scala, C"

print(languages.split(","))

# %%
num_list = [5, 6, 8, 7, 9]

num_list.insert(3,10)
print(num_list)

# %%
for i in range(5,25):
    print(i)

# %%
num = [2, 4, 6, 8]

new_list = [i ** 2 for i in num]
print(new_list)

# %%
for i in range(1,11):
    print(i)

# %%
num_tuple = (5, 8, 13, 2, 17, 1)

max_num = max(num_tuple)

new_list = list(num_tuple)

new_list.remove(max_num)
new_list.sort()
print(tuple(new_list))

# %%
myList = ['Lenovo', ' Dell', ' Acer', ' Asus', ' HP']

print(",".join(myList))

# %%
for i in range(-10,0):
    if i % 2 ==0:
        print(i)

# %%
n = 5623

print(str(n)[::-1])

# %%
num = [2, 4, 6, 8]

new_num = [(i,i**2,i**3) for i in num]
print(new_num)

# %%
set1 = {1, 2, 3, 4, 5}
set2 = {4, 5, 6, 7}

print(set1.symmetric_difference(set2))

print(set1 ^ set2)

# %%
myDict = {1:'One', 2:'Two', 3:'Three'}

print(myDict.keys())

# %%
set1 = {1, 2, 3, 4, 5}
set2 = {4, 5, 6, 7}

print(set1 & set2)

# %%
color = {1:'Red', 2:'Orange', 3:'White', 4:'Brown', 5:'Yellow'}
del color[3]
color[7] = "Black"
print(color)

# %%
set1 = {2, 4, 6}
set2 = {2, 4, 6, 8, 10}

print(set1.issubset(set2))

# %%
myDict1 = {1:'One', 2:'Two', 3:'Three'}
myDict2 = {4:'Four', 5:'Five', 6:'Six'}

myDict1.update(myDict2)
print(myDict1)

# %%
set1 = {2, 3, 4, 5}
set2 = {2, 4, 6, 8}

print(set1-set2)
print(set1.difference(set2))

# %%
import copy
student_details = {101:'Judy', 102:'Victor', 103:'Sam'}
replica = copy.deepcopy(student_details)
replica[103] = "Sally" 
print(student_details)
print(replica)

# %%
myTuple = ('Red', 'Blue', 'Green', 'Red', 'Orange', 'Green')

newset = set(myTuple)
print(tuple(newset))

# %%
newdict = dict((i, i** 3) for i in range(6))
print(newdict)

# %%
# %sql
SELECT 
    e.name,
    b.bonus
FROM Employee e
LEFT JOIN Bonus b
    ON e.empId = b.empId
WHERE b.bonus < 1000 OR b.bonus IS NULL;

from pyspark.sql.functions import col

employee_df.alias("e").join(bonus_df.alias("b"), col("e.empId")==col("b.empId"), "left").filter(col("b.bonus")<1000 | col("b.bonus").isNull()

# %%
from datetime import datetime

current_time = datetime.now()
print(current_time)

# %%
dob_time = datetime(1995, 6, 14, 10, 37, 50, 0)

print(dob_time.month)
print(dob_time.minute)

# %%
given_date = datetime(2011, 10, 12)
formatted = given_date.strftime("%d %b %Y - %a")
print(formatted)

# %%
given_date = datetime(2008, 5, 15)
dt1 = given_date.strftime("%A")
print(dt1)

# %%
from datetime import timedelta
given_date = datetime(2016, 2, 27, 11, 30, 0)

newtime = given_date + timedelta(days=2,hours=10)
print(newtime)

# %%
date_1 = datetime(2020, 7, 21).date()
date_2 = datetime(2020, 3, 10).date()

print(date_1 - date_2)

# %%
myString = "Oct 12 2002 12:45 PM"

datetime.strptime(myString, "%b %d %Y %I:%M %p")

# %%
td = datetime.now()
print(td)

# %%
oneday = timedelta(days=1)

print("Yesterday : " + (td-oneday).strftime("%Y-%m-%d"))

# %%
from datetime import timedelta
given_date = datetime(2020, 10, 17)

for i in range(1,6):
    td = timedelta(days=i)
    print(given_date+td)

# %%
tuple_1 = (22, 65, 12, 54)

print(tuple_1[::-1])

# %%
myList = [(2, 14, 'David'), [2, 7], 'Shaun']

print(myList[0][2])

# %%
mySet = {2, 4, 6}
myDict = {'A':'John', 'B':'Emma', 'C':'Sam'}

keys = myDict.keys()
print(keys)

for i in keys:
    mySet.add(i)

print(mySet)

# %%
set_1 = {2, 4, 6, 8}
set_2 = {6, 8, 10, 12}

print(set_1.union(set_2))

# %%
from datetime import time,datetime,timedelta

date = datetime.today().date()

first_sec = datetime.combine(date,time(0,0,0))
last_sec = datetime.combine(date,time(23,59,59))

print(first_sec)
print(last_sec)

# %%
num = 8842

print(len(str(num)))

# %%
num_list = [[2, 8, 11], [4, 5, 7, 12], [8, 9, 10, 11], [19, 13, 7], [2, 5, 16]]

print(max(num_list,key=sum))
print(min(num_list,key=sum))

# %%
fruits_string = "Apple, Banana, Mango, Kiwi, Guava, Grapes, Pomegranate, Orange, Watermelon"

print(fruits_string.split(","))

# %%
sample_text = "Python is a high-level and general-purpose programming language"

list_str = sample_text.split()

reverse_words_list = list_str[::-1]

print(" ".join(reverse_words_list))

# %%
heights = [177, 160, 171, 163, 168,  175, 176, 183, 162, 170]

heights.sort()

print(heights[:-4:-1])

# %%
list_1 = [5, 10, 15, 20, 25, 30, 35]
list_2 = [7, 14, 21, 28, 35, 42, 49]

odd_index_list = list_1[1::2]
even_index_list = list_2[::2]

print(odd_index_list+even_index_list)

# %%
num_1 = {'a' : 5,'s' : 7,'x' : 11,'m' : 12,'o' : 8}
num_2 = {'r' : 12,'x' : 9,'n' : 8,'m' : 12,'q' : 10}

k1 = num_1.keys()
k2 = num_2.keys()

print(set(k1).intersection(set(k2)))

i1 = num_1.items()
i2 = num_2.items()

print(set(i1).intersection(set(i2)))

print(set(k1).union(set(k2)))
print(set(k1)- set(k2))

new_set = set(k1)- set(k2)

dict3 = dict()

for i in new_set:
    dict3[i] = num_1[i]
    
print(dict3)

# %%
sample_text = "Learning Journal 2020"

alpha = ""
digit = ""

for char in sample_text:
    if char.isalpha():
        alpha += char
    elif char.isdigit():
        digit += char

print(len(alpha))
print(len(digit))

# %%
myList = [2, 8, [10, 20, [40, 60, [90, 100], 30, 70], 80], 50]

myList[2][2][2].insert(2,200)

print(myList)

# %%
set_1 = {2, 8, 19, 13, 24, 55, 48, 93}
set_2 = {7, 11, 55, 84, 8, 65, 73, 13}

set_3 = set_1 & set_2

print(set_3)

set_4 = set_1 - set_3

print(set_4)

# %%
start = 20
end = 60

for i in range(start,end+1):
    for j in range(2,int(i/2)+1):
        if i%j==0:
            break
    else:
        print(i)

# %%
letters_list = ['H', 'R', 'S']
result = []
for i in range(1,4):
    for j in letters_list:
        result.append(j+str(i))

print(result)

# %%
result = []
for i in range(1,101):
    if i%3==0 and i%5==0:
        result.append(i)
print(result)

# %%
poem = "Centre of equal daughters, equal sons,All, all alike endeared, grown, ungrown, young or old,Strong, ample, fair, enduring, capable, rich,Perennial with the Earth, with Freedom, Law and Love,A grand, sane, towering, seated Mother,Chaired in the adamant of Time"

new_poem = ""

vowel = "aeiou"

for char in poem.lower():
    if char not in vowel:
        new_poem += char

print(new_poem)

# %%
python_info = "Python is an interpreted, high-level, and general-purpose programming language.Python is dynamically typed and garbage-collected.Python was created in the late 1980s as a successor to the ABC language, Python 2.0.Python 3.0 was released in 2008.A non-profit organization, the Python Software Foundation, manages and directs resources for Python development."

import re

l = re.findall(r"Python", python_info)
print(len(l))

# %%
def func(a):
    for a in range(5,11):
        return True
    return False
print(func(7))

# %%
numlist = range(5,11)

l = lambda x:x in numlist
print(l(7))

# %%
lambda x,y:x+y

# %%
def func(a,b):
    addition = a+b
    sub = a-b
    return addition,sub

# %%
l = lambda x,y:(x+y,x-y)

print(l(5,6))

# %%
def result(name,outcome='Pass'):
    print(name,outcome)

# %%
result('sam',outcome='Fail')

# %%
n = [2, 3, 5, 6, 8, 9]
print(n[1::2])

# %%
l= map(lambda x:x[1::2],n)

# %%
print(l)

# %%
def func(*numlist):
    return numlist[1::2]

# %%
print(func(2, 3, 5, 6, 8, 9))

# %%
conutries = 'Austraiia', 'India', 'Austria', 'America', 'Russia', 'Iran'

def country(*args):
    for country in args:
        if country.startswith('A'):
            print(country)
country(*conutries)

# %%
candidate_details = [('Harry', 168), ('Jhonny', 160), ('Brad', 178), ('Chris', 172)]

candidate_details.sort(key=lambda x:x[1])
print(candidate_details)

# %%
map_details = {'Park':101, 'Zoo':102, 'Mall':103}

def findvalue(**dict1):
    print(map_details['Mall'])

# %%
findvalue(**map_details)

# %%
print(t)

# %%
list_1 = [1, 5, 8]
list_2 = [3, 2, 5]
list_3 = [2, 3, 6]

result = map(lambda x,y,z: x+y+z, list_1, list_2, list_3)

# %%
print(list(result))

# %%
try:
    n = int(input("please enter a number"))
    print("entered number is "+ str(n))
except ValueError:
    print("please enter a valid number")
print("finsished")

# %%
try:
    myfile = open("Users\XW334BQ\OneDrive - EY\Desktop\dataengg.txt","r")
    for line in myfile:
        print(line)
except FileNotFoundError:
    print("file not found")

# %%
x = 2
if x==2:
    print("x is 2")
else:
    print("x is not 2")

# %%
msg = 'Don\'t run in the park.'

print(msg)

# %%
try:
    num = (5, 7, 9, 11)
    num.append(13)
except AttributeError:
    print("AttributeError: 'tuple' object has no attribute 'append'")

# %%
def getData(data, index):
     return data[index]
 
names = ['Alpha', 'Victor', 'Charles']
try:
    getData(names, 5)
except IndexError:
    print("IndexError: list index out of range")

# %%
def add_elements(data_1, data_2, index):
    return data_1[index] + data_2[index]


numList_1 = [1, 5, 9, 15]
numList_2 = [2, 7, 11, 'a']

try:
    add_elements(numList_1, numList_2, 3)
except IndexError:
    print("IndexError: list index out of range")

except TypeError:
    print("TypeError: unsupported operand type(s) for +: 'int' and 'str'")

# %%
from datetime import date,datetime
try:
    given_date = datetime(2010, 6)
    newdate = given_date.strftime("%A %d %B %Y")
    print(newdate)
except:
    print('Oops! An error occurred.')

# %%
def reversestr(inputstring):
    if len(inputstring)%2==0:
        print(inputstring[::-1])
    else:
        print("len is not a even")

# %%
try:
    reversestr(65)
except TypeError:
    print("TypeError: 'int' object is not subscriptable")

# %%
def extractletter(inputstr):
    if len(inputstr)==10:
        print(inputstr[:10])
    else:
        raise ValueError("'Oops! Too short string.")

# %%
try:
    extractletter("ranjan")
except ValueError as e:
    print(e)

# %%
try:
    n = int(input("Enter the number"))
    sqr = lambda x:x**2
    sqr(n)
except ValueError:
    print("Please enter numeric value")
except:
    print("error occurred")

# %%
class InvalidNumError(Exception):
    pass

def result(marks):
    if marks < 0 or marks > 100:
        raise InvalidNumError("Invalid marks")
    else:
        print("Result processing")

# %%
try:
    result(99)
except InvalidNumError as e:
    print(e)

# %%
from pathlib import Path

path = Path("C:/Users/XW334BQ/OneDrive - EY/Desktop/textdoc.txt")



import os
print(os.path.exists(path))   # Must be True
